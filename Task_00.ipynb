# %%
"""

Reg No: 2017331101
Name: Asif Idris Tuhin

"""


import matplotlib.pyplot as plt
import numpy as np
from math import pi




plt.figure(1,figsize=(20,5))
x=np.arange(0,3,0.01)
y=np.sin(2*pi*2*x)
plt.plot(x,y)
plt.title("Analog Signal without generalization",fontsize=15)
plt.xlabel("t")
plt.ylabel("X(t)",fontsize=13)




# X(t)= aSin(2πft + Phase)

def Signal_Generator(a,f,t,phase=0):
  x=a* np.sin(2*pi*f*t + phase)
  return x

def draw_CosCurve(a,f,t,phase=0):
  x=a* np.cos(2*pi*f*t + phase)
  return x


t=np.linspace(0,3,200)

plt.figure(2,figsize=(20,5))
x=Signal_Generator(7,2,t)
plt.plot(t,x)
plt.title("Signal with amplitude = 7 , Frequency = 2 and Phase = 0",fontsize=15)
plt.xlabel("t")
plt.ylabel("X(t)",fontsize=13)


plt.figure(3,figsize=(20,5))
x=Signal_Generator(7,2,t,90)
plt.plot(t,x)
plt.title("Cos Wave =  signal with amplitude = 7 , Frequency = 2 and Phase = 90",fontsize=15)
plt.xlabel("t")
plt.ylabel("X(t)",fontsize=13)




plt.figure(4,figsize=(20,5))
x=draw_CosCurve(7,2,t)
plt.plot(t,x)
plt.title("Cos Wave by Cos function",fontsize=15)
plt.xlabel("t")
plt.ylabel("X(t)",fontsize=13)



plt.figure(5,figsize=(20,5))

plt.suptitle("Different plots in subplot",fontsize=20)

x=Signal_Generator(7,2,t)
plt.subplot(1,2,1)
plt.scatter(t,x)
plt.title("Scatter Plot",fontsize=15)
plt.xlabel("t")
plt.ylabel("X(t)",fontsize=13)


x=Signal_Generator(7,2,t)
plt.subplot(1,2,2)
plt.stem(t,x)
plt.title("Stem Plot",fontsize=15)
plt.xlabel("t")
plt.ylabel("X(t)",fontsize=13)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:81: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# Text(0, 0.5, 'X(t)')

# %%
import matplotlib.pyplot as plt
import numpy as np
from math import pi


def generate_Digital_Signal(bsig):
  sym_len=50

  rand_n=bsig
  
  no_bit=np.size(rand_n)

  #Generate Signal

  sig=np.zeros(sym_len*no_bit)

  id_n=[]
  for i,j in enumerate(rand_n):
    if j=='1':
      id_n.append(i)

  for i in id_n:
    temp1= int(i*sym_len)
    sig[temp1:temp1+sym_len]=1

  return sig




inp= input("Enter a bit string: ")
rand_n=list(inp)

sig=generate_Digital_Signal(rand_n)

space_separated = " ".join(rand_n)

plt.figure(figsize=(20,5))
plt.plot(sig,"blue")
plt.title('Digital signal')
plt.xlabel(space_separated,fontsize=15)
# Out:
# Enter a bit string: 101010
# Text(0.5, 0, '1 0 1 0 1 0')

# %% [markdown]
# **Basic properties of signal and some signals like step signal,impulse signal**

# %%
import matplotlib.pyplot as plt
import numpy as np
from math import pi


t=np.linspace(0,3,301)

x1=Signal_Generator(1,3,t)
x2=Signal_Generator(1,7,t)
x3=Signal_Generator(1,11,t)
y=x1+x2+x3

plt.figure(figsize=(20,11))
plt.suptitle("Three Sinusoidal Signals and One Composite Signal of those signals",fontsize=17)
plt.subplot(2,3,1)
plt.plot(t,x1,"red")
plt.title("Signal-1",fontsize=15)
plt.xlabel("t")
plt.ylabel("x1(t)",fontsize=13)

plt.subplot(2,3,2)
plt.plot(t,x2,"blue")
plt.title("Signal-2",fontsize=15)
plt.xlabel("t")
plt.ylabel("x2(t)",fontsize=13)

plt.subplot(2,3,3)
plt.plot(t,x3,"green")
plt.title("Signal-3",fontsize=15)
plt.xlabel("t")
plt.ylabel("x3(t)",fontsize=13)

plt.subplot(2,1,2)
plt.plot(t,y)
plt.title("Signal-1 +Signal-2 +Signal-3",fontsize=15)
plt.xlabel("t")
plt.ylabel("y(t)=x1(t)+x2(t)+x3(t)",fontsize=13)
# Out:
# Text(0, 0.5, 'y(t)=x1(t)+x2(t)+x3(t)')

# %%
Fs=50 #sampling frequency
T=1/Fs
n=np.arange(0,3,T)



f=3 #frequency
a=1 #amplitude
x=Signal_Generator(a,f,n)

plt.figure(figsize=(20,11))

plt.subplot(3,1,1)
plt.stem(n,x)
plt.title("Taken sample from signal-1 with fs=50",fontsize=15)


y = Signal_Generator(1,3,n) + Signal_Generator(1,7,n) + Signal_Generator(1,11,n)
plt.subplot(3,1,2)
plt.stem(n,y)
plt.title("Taken sample from the Composite signal with fs=50",fontsize=15)

Fs=200 #sampling frequency
T=1/Fs
n=np.arange(0,3,T)
y = Signal_Generator(1,3,n) + Signal_Generator(1,7,n) + Signal_Generator(1,11,n)
plt.subplot(3,1,3)
plt.stem(n,y)
plt.title("Taken sample from the Composite signal with fs=200",fontsize=15)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:20: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# ...

# %%
plt.figure(figsize=(20,11))

n= np.arange(-10,11,1)
l=np.size(n)
impulse=np.zeros(l)
for i,j in enumerate(n):
  # print("i= " ,i ,"j= ",j)
  if j==0 :
    impulse[i]=1
    break
plt.subplot(2,1,1)
plt.stem(n,impulse)
plt.title('Impulse Signal')
plt.xlabel('Sample'); plt.ylabel('Amplitude')


stp=np.zeros(l)
for i,j in enumerate(n):
  # print("i= " ,i ,"j= ",j)
  if j>=0 :
    stp[i]=1

plt.subplot(2,1,2)
plt.stem(n,stp)
plt.title('Step Signal')
plt.xlabel('Sample'); plt.ylabel('Amplitude')

plt.tight_layout
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   del sys.path[0]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:25: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# <function matplotlib.pyplot.tight_layout>
